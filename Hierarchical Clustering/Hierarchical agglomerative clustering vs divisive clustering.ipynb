# %% [markdown]
# ### Hierarchical agglomerative clustering vs divisive clustering

# %% [markdown]
# #### Implementation of hierarchical agglomerative clustering
# #### Clustering of unlabeled data can be performed with the module sklearn.cluster.
# #### https://scikit-learn.org/stable/modules/clustering.html
# #### https://scikit-learn.org/stable/modules/generated/sklearn.cluster.AgglomerativeClustering.html

# %%
from sklearn.cluster import AgglomerativeClustering
import numpy as np
import matplotlib.pyplot as plt

# randomly chosen dataset
X = np.array([[1, 2], [1, 4], [1, 0],[2,2],[3,4],[4,4],
              [5,5],[5,4],[4,5],[4, 2], [4, 4], [4, 0]])

plt.scatter(X[:,0],X[:,1])
plt.show()

clustering = AgglomerativeClustering(n_clusters=3,linkage='ward')

# Fit and return the result of each sample's clustering assignment.
clustered = clustering.fit_predict(X)

# plot results
plt.scatter(X[:,0],X[:,1], c=clustered)
plt.show()

# print the class labels
print(clustering.labels_)
# Out:
# [0 0 0 0 1 1 1 1 1 2 1 2]

# %% [markdown]
# #### Dendrograms are used to divide a given cluster into many different clusters.

# %%
import numpy as np
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt

# randomly chosen dataset
X = np.array([[1, 2], [1, 4], [1, 0],[2,2],[3,4],[4,4],
              [5,5],[5,4],[4,5],[4, 2], [4, 4], [4, 0]])


# Perform hierarchical clustering
Z = linkage(X, 'ward')

# Plot dendrogram
# Visulaizing the working of the dendograms
dendrogram(Z)

plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Data point')
plt.ylabel('Distance')
plt.show()
