# %%
#Access the stored variables
# %store -r before2015
# %store -r after2015
# %store -r reaction

# %% [markdown]
# ### Visualizing yearwise growth of engagements on posts for data before and data fter 2015
# - We can observe that number of likes and number of reactions increased drastically over the years.
# - Mostly before 2015 prominent engagements were only likes and reactions.

# %%
before2015.groupby('year')[reaction].sum()
# Out:
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# year
# 2012          12389          4053         110      12389          0         0
# 2013          45524          3018         513      45524          0         0
# 2014         141631          4623         841     141631          0         0
# 2015         519039         11359        2936     519039          0         0
#
#       num_hahas  num_sads  num_angrys
# year
# 2012          0         0           0
# 2013          0         0           0
# 2014          0         0           0
# 2015          0         0           0

# %%
before2015.groupby('year')[reaction].sum().plot()
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# ### Visualizing yearwise growth for data after 2015
# - We can observe that number of comments increased drastically over the years.
# - Unlike before 2015, other engagements also show an increasing trend over the years.

# %%
after2015.groupby('year')[reaction].sum()
# Out:
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# year
# 2016         105220         61065        4105     101501       2803       424
# 2017         259280        731519       90793     227617      27497      1732
# 2018         491654        763002      182472     421716      58948      6613
#
#       num_hahas  num_sads  num_angrys
# year
# 2016        150       329          13
# 2017       1506       646         263
# 2018       3229       653         495

# %%
after2015.groupby('year')[reaction].sum().plot()
# Out:
# <Axes: xlabel='year'>

# %%
before2015.groupby('hour')[reaction].sum().plot()
# Out:
# <Axes: xlabel='hour'>

# %%
after2015.groupby('hour')[reaction].sum().plot()
# Out:
# <Axes: xlabel='hour'>

# %%
before2015.groupby('month')[reaction].sum().plot()
# Out:
# <Axes: xlabel='month'>

# %%
after2015.groupby('month')[reaction].sum().plot()
# Out:
# <Axes: xlabel='month'>

# %%
before2015.groupby('dayofweek')[reaction].sum().plot()
# Out:
# <Axes: xlabel='dayofweek'>

# %%
after2015.groupby('dayofweek')[reaction].sum().plot()
# Out:
# <Axes: xlabel='dayofweek'>
